# %%
import requests

cookies = {
    'tracker_glob_new': '8g3qSkJ',
    'tracker_session': '4msDLqO',
    '_gcl_au': '1.1.342171281.1650348032',
    '_sp_ses.13cb': '*',
    '_gid': 'GA1.2.1934147911.1650348052',
    '_hjFirstSeen': '1',
    '_hjSession_2754176': 'eyJpZCI6ImYyY2QwY2VmLWIyN2MtNGM0My1iZWU1LTNjNjkyYzNjMjQwMiIsImNyZWF0ZWQiOjE2NTAzNDgwNjc4MjcsImluU2FtcGxlIjpmYWxzZX0=',
    '_hjAbsoluteSessionInProgress': '1',
    '_hjSessionUser_2754176': 'eyJpZCI6IjBhZmMyMzNiLTkzZTAtNTA4Mi05Y2Y0LTU1YTEwMjY2MzI2MyIsImNyZWF0ZWQiOjE2NTAzNDgwNjQyOTEsImV4aXN0aW5nIjp0cnVlfQ==',
    '_gat_UA-13212406-1': '1',
    'TS01e4b47a': '010231059115a96614f4c3ed5286123feac8f64227091b453284c1f9dfb41344d1e5a4b9d5703203d98ddfe81629617f7ad3a56fb8300b1ef3ff13c52003aad9fa2dea0d0132b343931e050e8819bca79e1a327399',
    '_ga_4S04WR965Q': 'GS1.1.1650348032.1.1.1650348449.0',
    '_ga_LR50FG4ELJ': 'GS1.1.1650348032.1.1.1650348449.53',
    '_ga': 'GA1.2.951384881.1650348051',
    '_conv_v': 'vi%3A1*sc%3A1*cs%3A1650348052*fs%3A1650348052*pv%3A6',
    '_conv_s': 'si%3A1*sh%3A1650348052355-0.9042676499534048*pv%3A6',
    '_sp_id.13cb': 'c973b6b6-69d7-48a3-b0ce-9b50f67a78a4.1650348034.1.1650348457.1650348034.c9c7765c-a2eb-466c-b07f-50b743ce9420',
}

headers = {
    'authority': 'api.digikala.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'en-US,en;q=0.9,fa-IR;q=0.8,fa;q=0.7',
    'origin': 'https://www.digikala.com',
    'referer': 'https://www.digikala.com/',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="100", "Google Chrome";v="100"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.75 Safari/537.36',
    'x-web-client': 'desktop',
    'x-web-optimize-response': '1',
}

# %%
params = {
    'category_id': '5966',
}

response = requests.get('https://api.digikala.com/v1/best-selling/', headers=headers, params=params, cookies=cookies)

response.json()
# Out:
# {'status': 200,
#  'data': {'products': [{'id': 5086666,
#     'title_fa': 'هندزفری بلوتوثی مدل \xa0inpods 12',
#     'title_en': '',
#     'url': {'uri': '/product/dkp-5086666/هندزفری-بلوتوثی-مدل-inpods-i12'},
#     'status': 'marketable',
#     'has_quick_view': False,
#     'digiplus': {'services': ['ارسال رایگان', 'امکان ارسال فوری (شهر تهران)'],
#      'is_jet_eligible': True,
#      'cash_back': 0,
#      'is_general_location_jet_eligible': False},
#     'data_layer': {'brand': 'متفرقه',
#      'category': '[AC,هدفون و هندزفری]',
#      'metric6': 12003,
#      'dimension2': 0,
#      'dimension6': 0,
#      'dimension7': 'none',
#      'dimension9': 3.7,
#      'dimension11': 0,
#      'dimension20': 'marketable'},
#     'images': {'main': {'url': ['https://dkstatics-public.digikala.com/digikala-products/e4b2145a5e77bdc30aafff78bba4734798ac8d68_1620202335.jpg?x-oss-process=image/resize,m_lfit,h_300,w_300/quality,q_80']}},
# ...

# %%
params = {
    'order': 'created_at',
}

response = requests.get('https://api.digikala.com/v1/product/5086666/comments/', headers=headers, params=params, cookies=cookies)

response.json()
# Out:
# {'status': 200,
#  'data': {'ratings': [{'id': 306,
#     'title': 'کیفیت عمومی پخش صدا',
#     'value': 69.8},
#    {'id': 307, 'title': 'امکانات و قابلیت ها', 'value': 69.4},
#    {'id': 308, 'title': 'ارگونومی', 'value': 68.9},
#    {'id': 309, 'title': 'کیفیت ساخت', 'value': 68.6},
#    {'id': 310, 'title': 'ارزش خرید در برابر قیمت', 'value': 71.2}],
#   'comments': [{'id': 34009877,
#     'title': 'بی کیفیت',
#     'body': 'سلام\n\nمن مشکی سفارش دادم،یکیش کار نمیکنه،کیفیت صداش هم خیلی پایینه.به حدی که منصرف شدم از مرجوع کردنش',
#     'created_at': '30 فروردین 1401',
#     'rate': 1,
#     'reactions': {'likes': 0, 'dislikes': 0},
#     'recommendation_status': 'not_recommended',
#     'is_buyer': True,
#     'user_name': 'عبدالرضا بهادری',
#     'is_anonymous': False,
#     'purchased_item': {'seller': {'id': 139181,
#       'title': 'گنجینه کالا',
#       'code': 'AFCVW',
#       'url': 'https://www.digikala.com/seller/AFCVW/',
#       'rating': {'total_rate': 0,
# ...
